# %% [markdown]
# <a href="https://colab.research.google.com/github/kaho-morisaki/kadai/blob/main/midorikiiro_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 画像分類実践
#
# (colab) ページ上部の ランタイム → ランタイムのタイプを変更 → ハードウェアアクセラレータを「GPU」に変更 → 保存
# 深層学習では、簡単な計算を大量に行い学習を進めます。こういった計算にはGPUが適しています。
#
# [参考資料](https://aiacademy.jp/texts/show/?id=164)

# %% [markdown]
# ### パッケージの準備

# %%
# 必要なパッケージをインストール
# !から始まる行はshell command (Pythonではない)
# !pip install icrawler

# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting icrawler
#   Downloading icrawler-0.6.6-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from icrawler) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from icrawler) (4.9.2)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from icrawler) (2.27.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from icrawler) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from icrawler) (8.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->icrawler) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->icrawler) (3.4)
# Installing collected packages: icrawler
# Successfully installed icrawler-0.6.6

# %% [markdown]
# ### webから画像をかき集める：クローリング
#
# 今回は猫・犬の画像分類器を作成します。猫と犬の画像が必要なので、webからかき集めてきます。収集した画像はランタイムのディスク領域に保存されるため、ランタイムのセッションを閉じると削除されます。
#
# *クローリングの結果は毎回変わるため、この方法では再現性は得られません

# %%
from icrawler.builtin import BingImageCrawler
import logging

n_img = 100
class1_name = "cat"
class1_keyword = "緑色"
class2_name = "dog"
class2_keyword = "黄色"

# 猫の画像を取得
crawler = BingImageCrawler(storage={"root_dir": class1_name}, log_level=logging.INFO, parser_threads=2, downloader_threads=4,)
crawler.crawl(keyword=class1_keyword, max_num=n_img)  # 検索キーワードはひらがなの方がちゃんと動物が出る可能性が高い気がする

# 犬の画像を取得
crawler = BingImageCrawler(storage={"root_dir": class2_name}, log_level=logging.INFO, parser_threads=2, downloader_threads=4,)
crawler.crawl(keyword=class2_keyword, max_num=n_img)

# ダウンロード用のzipファイル生成
# !zip -r $class1_name $class1_name
# !zip -r $class2_name $class2_name
# Out:
# ERROR:downloader:Response status code 403, file https://c.wallhere.com/photos/be/df/minimalism_green_background_simple_textured_texture_pattern-257768.jpg
# ERROR:downloader:Exception caught when downloading file https://cleverlyhome.tokyo/wp-content/uploads/2017/07/plant-71249_960_720.jpg, error: HTTPSConnectionPool(host='cleverlyhome.tokyo', port=443): Max retries exceeded with url: /wp-content/uploads/2017/07/plant-71249_960_720.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)'))), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://cleverlyhome.tokyo/wp-content/uploads/2017/07/plant-71249_960_720.jpg, error: HTTPSConnectionPool(host='cleverlyhome.tokyo', port=443): Max retries exceeded with url: /wp-content/uploads/2017/07/plant-71249_960_720.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)'))), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://cleverlyhome.tokyo/wp-content/uploads/2017/07/plant-71249_960_720.jpg, error: HTTPSConnectionPool(host='cleverlyhome.tokyo', port=443): Max retries exceeded with url: /wp-content/uploads/2017/07/plant-71249_960_720.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)'))), remaining retry times: 0
# ERROR:downloader:Response status code 400, file https://smlycdn.akamaized.net/data/product2/2/a4f58faf234a27a8914b90a0b9eeaeab8d2f0388_l.jpg
# ERROR:downloader:Exception caught when downloading file http://pic0.huitu.com/res/20191002/2272719_20191002115531900148_1.jpg, error: HTTPConnectionPool(host='pic0.huitu.com', port=80): Max retries exceeded with url: /res/20191002/2272719_20191002115531900148_1.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21cfa0>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic0.huitu.com/res/20191002/2272719_20191002115531900148_1.jpg, error: HTTPConnectionPool(host='pic0.huitu.com', port=80): Max retries exceeded with url: /res/20191002/2272719_20191002115531900148_1.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21d2d0>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic0.huitu.com/res/20191002/2272719_20191002115531900148_1.jpg, error: HTTPConnectionPool(host='pic0.huitu.com', port=80): Max retries exceeded with url: /res/20191002/2272719_20191002115531900148_1.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21d030>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic22.nipic.com/20120620/10209170_113657419119_2.jpg, error: HTTPConnectionPool(host='pic22.nipic.com', port=80): Max retries exceeded with url: /20120620/10209170_113657419119_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21c1c0>, 'Connection to pic22.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic22.nipic.com/20120620/10209170_113657419119_2.jpg, error: HTTPConnectionPool(host='pic22.nipic.com', port=80): Max retries exceeded with url: /20120620/10209170_113657419119_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21e4a0>, 'Connection to pic22.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic25.nipic.com/20121117/9332555_112549235000_2.jpg, error: HTTPConnectionPool(host='pic25.nipic.com', port=80): Max retries exceeded with url: /20121117/9332555_112549235000_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21dff0>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic25.nipic.com/20121117/9332555_112549235000_2.jpg, error: HTTPConnectionPool(host='pic25.nipic.com', port=80): Max retries exceeded with url: /20121117/9332555_112549235000_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21f550>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic25.nipic.com/20121117/9332555_112549235000_2.jpg, error: HTTPConnectionPool(host='pic25.nipic.com', port=80): Max retries exceeded with url: /20121117/9332555_112549235000_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21f460>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic29.nipic.com/20130511/9252150_174155225308_2.jpg, error: HTTPConnectionPool(host='pic29.nipic.com', port=80): Max retries exceeded with url: /20130511/9252150_174155225308_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc6a0550>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic29.nipic.com/20130511/9252150_174155225308_2.jpg, error: HTTPConnectionPool(host='pic29.nipic.com', port=80): Max retries exceeded with url: /20130511/9252150_174155225308_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc6a0bb0>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic29.nipic.com/20130511/9252150_174155225308_2.jpg, error: HTTPConnectionPool(host='pic29.nipic.com', port=80): Max retries exceeded with url: /20130511/9252150_174155225308_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc1e7f10>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic22.nipic.com/20120620/10209170_113657419119_2.jpg, error: HTTPConnectionPool(host='pic22.nipic.com', port=80): Max retries exceeded with url: /20120620/10209170_113657419119_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21f2b0>, 'Connection to pic22.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic17.nipic.com/20111109/4860204_104818740110_2.jpg, error: HTTPConnectionPool(host='pic17.nipic.com', port=80): Max retries exceeded with url: /20111109/4860204_104818740110_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6a1a20>, 'Connection to pic17.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic19.nipic.com/20120329/199392_120310581000_2.jpg, error: HTTPConnectionPool(host='pic19.nipic.com', port=80): Max retries exceeded with url: /20120329/199392_120310581000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6a1750>, 'Connection to pic19.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic26.nipic.com/20130126/9252150_171446411155_2.jpg, error: HTTPConnectionPool(host='pic26.nipic.com', port=80): Max retries exceeded with url: /20130126/9252150_171446411155_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6a1990>, 'Connection to pic26.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic4.nipic.com/20090908/2429260_181951008930_2.jpg, error: HTTPConnectionPool(host='pic4.nipic.com', port=80): Max retries exceeded with url: /20090908/2429260_181951008930_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6a0730>, 'Connection to pic4.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic17.nipic.com/20111109/4860204_104818740110_2.jpg, error: HTTPConnectionPool(host='pic17.nipic.com', port=80): Max retries exceeded with url: /20111109/4860204_104818740110_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21eb90>, 'Connection to pic17.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic19.nipic.com/20120329/199392_120310581000_2.jpg, error: HTTPConnectionPool(host='pic19.nipic.com', port=80): Max retries exceeded with url: /20120329/199392_120310581000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc5d9120>, 'Connection to pic19.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic26.nipic.com/20130126/9252150_171446411155_2.jpg, error: HTTPConnectionPool(host='pic26.nipic.com', port=80): Max retries exceeded with url: /20130126/9252150_171446411155_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27c5b0>, 'Connection to pic26.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic4.nipic.com/20090908/2429260_181951008930_2.jpg, error: HTTPConnectionPool(host='pic4.nipic.com', port=80): Max retries exceeded with url: /20090908/2429260_181951008930_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6a08e0>, 'Connection to pic4.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic17.nipic.com/20111109/4860204_104818740110_2.jpg, error: HTTPConnectionPool(host='pic17.nipic.com', port=80): Max retries exceeded with url: /20111109/4860204_104818740110_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27cd60>, 'Connection to pic17.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic19.nipic.com/20120329/199392_120310581000_2.jpg, error: HTTPConnectionPool(host='pic19.nipic.com', port=80): Max retries exceeded with url: /20120329/199392_120310581000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27d390>, 'Connection to pic19.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic26.nipic.com/20130126/9252150_171446411155_2.jpg, error: HTTPConnectionPool(host='pic26.nipic.com', port=80): Max retries exceeded with url: /20130126/9252150_171446411155_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27c760>, 'Connection to pic26.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic4.nipic.com/20090908/2429260_181951008930_2.jpg, error: HTTPConnectionPool(host='pic4.nipic.com', port=80): Max retries exceeded with url: /20090908/2429260_181951008930_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27d900>, 'Connection to pic4.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic26.nipic.com/20121227/9252150_203119206300_2.jpg, error: HTTPConnectionPool(host='pic26.nipic.com', port=80): Max retries exceeded with url: /20121227/9252150_203119206300_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27e530>, 'Connection to pic26.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic33.nipic.com/20130924/6400131_151941509000_2.jpg, error: HTTPConnectionPool(host='pic33.nipic.com', port=80): Max retries exceeded with url: /20130924/6400131_151941509000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc5d9690>, 'Connection to pic33.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file https://img.599ku.com/ele_banner2/6557fb5043419ef5a7712b530e5c92ed.jpg, error: HTTPSConnectionPool(host='img.599ku.com', port=443): Max retries exceeded with url: /ele_banner2/6557fb5043419ef5a7712b530e5c92ed.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f90fc21f4c0>, 'Connection to img.599ku.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic26.nipic.com/20121227/9252150_203119206300_2.jpg, error: HTTPConnectionPool(host='pic26.nipic.com', port=80): Max retries exceeded with url: /20121227/9252150_203119206300_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27e320>, 'Connection to pic26.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic32.nipic.com/20130812/9252150_125956336347_2.jpg, error: HTTPConnectionPool(host='pic32.nipic.com', port=80): Max retries exceeded with url: /20130812/9252150_125956336347_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6b8400>, 'Connection to pic32.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic33.nipic.com/20130924/6400131_151941509000_2.jpg, error: HTTPConnectionPool(host='pic33.nipic.com', port=80): Max retries exceeded with url: /20130924/6400131_151941509000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21dfc0>, 'Connection to pic33.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file https://img.599ku.com/ele_banner2/6557fb5043419ef5a7712b530e5c92ed.jpg, error: HTTPSConnectionPool(host='img.599ku.com', port=443): Max retries exceeded with url: /ele_banner2/6557fb5043419ef5a7712b530e5c92ed.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f90fc6a1de0>, 'Connection to img.599ku.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic26.nipic.com/20121227/9252150_203119206300_2.jpg, error: HTTPConnectionPool(host='pic26.nipic.com', port=80): Max retries exceeded with url: /20121227/9252150_203119206300_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27c8e0>, 'Connection to pic26.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic32.nipic.com/20130812/9252150_125956336347_2.jpg, error: HTTPConnectionPool(host='pic32.nipic.com', port=80): Max retries exceeded with url: /20130812/9252150_125956336347_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27c580>, 'Connection to pic32.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic33.nipic.com/20130924/6400131_151941509000_2.jpg, error: HTTPConnectionPool(host='pic33.nipic.com', port=80): Max retries exceeded with url: /20130924/6400131_151941509000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27ccd0>, 'Connection to pic33.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic8.nipic.com/20100718/1384561_134517619032_2.jpg, error: HTTPConnectionPool(host='pic8.nipic.com', port=80): Max retries exceeded with url: /20100718/1384561_134517619032_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21f160>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic8.nipic.com/20100718/1384561_134517619032_2.jpg, error: HTTPConnectionPool(host='pic8.nipic.com', port=80): Max retries exceeded with url: /20100718/1384561_134517619032_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc5d96f0>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic8.nipic.com/20100718/1384561_134517619032_2.jpg, error: HTTPConnectionPool(host='pic8.nipic.com', port=80): Max retries exceeded with url: /20100718/1384561_134517619032_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc5d8c70>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file https://img.599ku.com/ele_banner2/6557fb5043419ef5a7712b530e5c92ed.jpg, error: HTTPSConnectionPool(host='img.599ku.com', port=443): Max retries exceeded with url: /ele_banner2/6557fb5043419ef5a7712b530e5c92ed.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f90fc6a1540>, 'Connection to img.599ku.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic19.nipic.com/20120317/7091614_160737916000_2.jpg, error: HTTPConnectionPool(host='pic19.nipic.com', port=80): Max retries exceeded with url: /20120317/7091614_160737916000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21dc00>, 'Connection to pic19.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic32.nipic.com/20130812/9252150_125956336347_2.jpg, error: HTTPConnectionPool(host='pic32.nipic.com', port=80): Max retries exceeded with url: /20130812/9252150_125956336347_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21cbb0>, 'Connection to pic32.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic4.nipic.com/20091210/3712172_103616528857_2.jpg, error: HTTPConnectionPool(host='pic4.nipic.com', port=80): Max retries exceeded with url: /20091210/3712172_103616528857_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21d450>, 'Connection to pic4.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic19.nipic.com/20120317/7091614_160737916000_2.jpg, error: HTTPConnectionPool(host='pic19.nipic.com', port=80): Max retries exceeded with url: /20120317/7091614_160737916000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27c3a0>, 'Connection to pic19.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic23.nipic.com/20120906/9252150_212226331109_2.jpg, error: HTTPConnectionPool(host='pic23.nipic.com', port=80): Max retries exceeded with url: /20120906/9252150_212226331109_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc5d9720>, 'Connection to pic23.nipic.com timed out. (connect timeout=5)')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://image5.suning.cn/content/catentries/00000000010424/000000000104247862/fullimage/000000000104247862_4f.jpg, error: HTTPConnectionPool(host='image5.suning.cn', port=80): Read timed out. (read timeout=5), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic4.nipic.com/20091210/3712172_103616528857_2.jpg, error: HTTPConnectionPool(host='pic4.nipic.com', port=80): Max retries exceeded with url: /20091210/3712172_103616528857_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21ead0>, 'Connection to pic4.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic19.nipic.com/20120317/7091614_160737916000_2.jpg, error: HTTPConnectionPool(host='pic19.nipic.com', port=80): Max retries exceeded with url: /20120317/7091614_160737916000_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21c0a0>, 'Connection to pic19.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic23.nipic.com/20120906/9252150_212226331109_2.jpg, error: HTTPConnectionPool(host='pic23.nipic.com', port=80): Max retries exceeded with url: /20120906/9252150_212226331109_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc6a1210>, 'Connection to pic23.nipic.com timed out. (connect timeout=5)')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic29.nipic.com/20130507/9252150_102449482399_2.jpg, error: HTTPConnectionPool(host='pic29.nipic.com', port=80): Max retries exceeded with url: /20130507/9252150_102449482399_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc59d090>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 2
# ERROR:downloader:Exception caught when downloading file http://pic29.nipic.com/20130507/9252150_102449482399_2.jpg, error: HTTPConnectionPool(host='pic29.nipic.com', port=80): Max retries exceeded with url: /20130507/9252150_102449482399_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21f4c0>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 1
# ERROR:downloader:Exception caught when downloading file http://pic29.nipic.com/20130507/9252150_102449482399_2.jpg, error: HTTPConnectionPool(host='pic29.nipic.com', port=80): Max retries exceeded with url: /20130507/9252150_102449482399_2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f90fc21da50>: Failed to establish a new connection: [Errno -2] Name or service not known')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic4.nipic.com/20091210/3712172_103616528857_2.jpg, error: HTTPConnectionPool(host='pic4.nipic.com', port=80): Max retries exceeded with url: /20091210/3712172_103616528857_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc27e410>, 'Connection to pic4.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
# ERROR:downloader:Exception caught when downloading file http://pic23.nipic.com/20120906/9252150_212226331109_2.jpg, error: HTTPConnectionPool(host='pic23.nipic.com', port=80): Max retries exceeded with url: /20120906/9252150_212226331109_2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f90fc21f5b0>, 'Connection to pic23.nipic.com timed out. (connect timeout=5)')), remaining retry times: 0
#   adding: cat/ (stored 0%)
#   adding: cat/000056.jpg (deflated 0%)
#   adding: cat/000014.jpg (deflated 10%)
#   adding: cat/000050.jpg (deflated 97%)
#   adding: cat/000062.jpg (deflated 1%)
#   adding: cat/000019.jpg (deflated 16%)
#   adding: cat/000048.jpg (deflated 79%)
#   adding: cat/000017.jpg (deflated 73%)
#   adding: cat/000055.jpg (deflated 3%)
#   adding: cat/000061.jpg (deflated 1%)
#   adding: cat/000036.jpg (deflated 0%)
#   adding: cat/000033.jpg (deflated 9%)
#   adding: cat/000037.jpg (deflated 0%)
#   adding: cat/000034.jpg (deflated 4%)
#   adding: cat/000046.jpg (deflated 2%)
#   adding: cat/000042.jpg (deflated 91%)
#   adding: cat/000021.jpg (deflated 0%)
#   adding: cat/000060.jpg (deflated 20%)
#   adding: cat/000023.jpg (deflated 7%)
#   adding: cat/000073.jpg (deflated 40%)
#   adding: cat/000059.jpg (deflated 50%)
#   adding: cat/000003.jpg (deflated 19%)
#   adding: cat/000043.jpg (deflated 2%)
#   adding: cat/000013.jpg (deflated 57%)
#   adding: cat/000040.jpg (deflated 95%)
#   adding: cat/000053.jpg (deflated 4%)
#   adding: cat/000052.jpg (deflated 3%)
#   adding: cat/000008.jpg (deflated 16%)
#   adding: cat/000016.jpg (deflated 88%)
#   adding: cat/000004.jpg (deflated 99%)
#   adding: cat/000027.jpg (deflated 0%)
#   adding: cat/000054.jpg (deflated 1%)
#   adding: cat/000041.jpg (deflated 6%)
#   adding: cat/000075.jpg (deflated 0%)
#   adding: cat/000001.jpg (deflated 72%)
#   adding: cat/000072.jpg (deflated 1%)
#   adding: cat/000067.jpg (deflated 0%)
#   adding: cat/000020.jpg (deflated 0%)
#   adding: cat/000049.jpg (deflated 12%)
#   adding: cat/000018.jpg (deflated 0%)
#   adding: cat/000051.jpg (deflated 1%)
#   adding: cat/000032.jpg (deflated 7%)
#   adding: cat/000007.jpg (deflated 6%)
#   adding: cat/000074.jpg (deflated 4%)
#   adding: cat/000039.jpg (deflated 33%)
#   adding: cat/000063.jpg (deflated 5%)
#   adding: cat/000011.jpg (deflated 1%)
#   adding: cat/000035.jpg (deflated 11%)
#   adding: cat/000071.jpg (deflated 0%)
#   adding: cat/000044.jpg (deflated 30%)
#   adding: cat/000012.jpg (deflated 20%)
#   adding: cat/000006.jpg (deflated 95%)
#   adding: cat/000026.jpg (deflated 0%)
#   adding: cat/000025.jpg (deflated 95%)
#   adding: cat/000064.jpg (deflated 0%)
#   adding: cat/000065.jpg (deflated 3%)
#   adding: cat/000030.jpg (deflated 1%)
#   adding: cat/000010.jpg (deflated 1%)
#   adding: cat/000029.jpg (deflated 14%)
#   adding: cat/000066.jpg (deflated 0%)
#   adding: cat/000002.jpg (deflated 95%)
#   adding: cat/000068.jpg (deflated 1%)
#   adding: cat/000038.jpg (deflated 26%)
#   adding: cat/000045.jpg (deflated 9%)
#   adding: cat/000022.jpg (deflated 31%)
#   adding: cat/000015.jpg (deflated 90%)
#   adding: cat/000009.jpg (deflated 1%)
#   adding: cat/000057.jpg (deflated 0%)
#   adding: cat/000024.jpg (deflated 3%)
#   adding: cat/000070.jpg (deflated 7%)
#   adding: cat/000069.jpg (deflated 0%)
#   adding: cat/000031.jpg (deflated 20%)
#   adding: cat/000047.jpg (deflated 9%)
#   adding: cat/000005.jpg (deflated 1%)
#   adding: cat/000058.jpg (deflated 37%)
#   adding: cat/000028.jpg (deflated 3%)
#   adding: dog/ (stored 0%)
#   adding: dog/000014.jpg (deflated 4%)
#   adding: dog/000050.jpg (deflated 35%)
#   adding: dog/000019.jpg (deflated 0%)
#   adding: dog/000048.jpg (deflated 75%)
#   adding: dog/000017.jpg (deflated 4%)
#   adding: dog/000036.jpg (deflated 3%)
#   adding: dog/000033.jpg (deflated 0%)
#   adding: dog/000037.jpg (deflated 1%)
#   adding: dog/000034.jpg (deflated 0%)
#   adding: dog/000046.jpg (deflated 67%)
#   adding: dog/000042.jpg (deflated 3%)
#   adding: dog/000021.jpg (deflated 5%)
#   adding: dog/000023.jpg (deflated 0%)
#   adding: dog/000003.jpg (deflated 73%)
#   adding: dog/000043.jpg (deflated 15%)
#   adding: dog/000013.jpg (deflated 2%)
#   adding: dog/000040.jpg (deflated 0%)
#   adding: dog/000053.jpg (deflated 0%)
#   adding: dog/000052.jpg (deflated 11%)
#   adding: dog/000008.jpg (deflated 11%)
#   adding: dog/000016.jpg (deflated 0%)
#   adding: dog/000004.jpg (deflated 45%)
#   adding: dog/000027.jpg (deflated 99%)
#   adding: dog/000054.jpg (deflated 0%)
#   adding: dog/000041.jpg (deflated 0%)
#   adding: dog/000001.jpg (deflated 95%)
#   adding: dog/000020.jpg (deflated 45%)
#   adding: dog/000049.jpg (deflated 97%)
#   adding: dog/000018.jpg (deflated 4%)
#   adding: dog/000051.jpg (deflated 8%)
#   adding: dog/000032.jpg (deflated 0%)
#   adding: dog/000007.jpg (deflated 0%)
#   adding: dog/000039.jpg (deflated 24%)
#   adding: dog/000011.jpg (deflated 30%)
#   adding: dog/000035.jpg (deflated 2%)
#   adding: dog/000044.jpg (deflated 74%)
#   adding: dog/000012.jpg (deflated 53%)
#   adding: dog/000006.jpg (deflated 3%)
#   adding: dog/000026.jpg (deflated 0%)
#   adding: dog/000025.jpg (deflated 0%)
#   adding: dog/000030.jpg (deflated 2%)
#   adding: dog/000010.jpg (deflated 3%)
#   adding: dog/000029.jpg (deflated 1%)
#   adding: dog/000002.jpg (deflated 64%)
#   adding: dog/000038.jpg (deflated 12%)
#   adding: dog/000045.jpg (deflated 0%)
#   adding: dog/000022.jpg (deflated 81%)
#   adding: dog/000015.jpg (deflated 68%)
#   adding: dog/000009.jpg (deflated 95%)
#   adding: dog/000024.jpg (deflated 1%)
#   adding: dog/000031.jpg (deflated 0%)
#   adding: dog/000047.jpg (deflated 5%)
#   adding: dog/000005.jpg (deflated 64%)
#   adding: dog/000028.jpg (deflated 19%)

# %% [markdown]
# ### 収集した画像の読み込み
#
# 画像をopencv (`cv2`) というモジュールで読み込みます。画像は`numpy`の`np.ndarray`という配列オブジェクトとして読み込まれます。
# `ndarray`で気にかけておくべきことは次の3つです。
# - 配列の次元 = ランク (`ndarray.ndim`)
# - 配列の形 (`ndarray.shape`)
# - 配列のデータ型 (`ndarray.dtype`)
#
# 一方で中身の個々の値に関しては、大きい配列ですと確認が難しいため、最大値や平均値など配列全体としての情報から期待している数値が入っているか推測することになります。
#
# <img src="https://qph.fs.quoracdn.net/main-qimg-30be20ab9458b5865b526d287b4fef9a" width="500" >
#
# 低次元の配列には名前がついています。
# - 0次元: スカラー
# - 1次元: ベクトル
# - 2次元: マトリックス
#
# これらを一般化した概念をテンソルと呼びます。

# %%
# ダウンロードした画像を全て同じ大きさにリサイズし、メモリに格納
import numpy as np
import cv2
from pathlib import Path  # ディスク上のファイル一覧を取得するなど、パスの操作に用いるモジュール

img_size = 64
imgs_cat = list()
imgs_dog = list()

for img_list, img_dir in ((imgs_cat, class1_name), (imgs_dog, class2_name)):
  # 画像パス一つずつを処理
  for impath in Path(img_dir).iterdir():
    # 画像読み込み: cv2.imread()
    img = cv2.imread(str(impath))
    if img is None: continue
    # 画像リサイズ
    img = cv2.resize(img, (img_size, img_size))
    img_list.append(img)

# listをndarrayに変換
imgs_cat = np.array(imgs_cat)
imgs_dog = np.array(imgs_dog)

# テンソルの情報を確認
print('imgs_cat.ndim =', imgs_cat.ndim)
print('imgs_cat.shape =', imgs_cat.shape)
print('imgs_cat.dtype =', imgs_cat.dtype)
print('')
print('imgs_dog.ndim =', imgs_dog.ndim)
print('imgs_dog.shape =', imgs_dog.shape)
print('imgs_dog.dtype =', imgs_dog.dtype)
# Out:
# imgs_cat.ndim = 4
# imgs_cat.shape = (75, 64, 64, 3)
# imgs_cat.dtype = uint8
#
# imgs_dog.ndim = 4
# imgs_dog.shape = (54, 64, 64, 3)
# imgs_dog.dtype = uint8

# %% [markdown]
# `cv2.imread()`関数で読み込んだ画像のデータ型は、デフォルトでは`np.uint8`という、符号なし（=マイナスを表現できない）8 bitの整数です。[0, 255]の範囲のみ表現可能です。
# `imgs_cat`は4次元配列で形が(n, 64, 64, 3)になっています。これは、最初の軸 (`axis = 0`) には画像の枚数nが、続く3つの次元には64 x 64 pixelの3チャネル (RGB) 画像が格納されているという意味になっています。
# (`cv2.imread()`で読み込んだ画像は、厳密にはチャネルの並びがBGRの順番になっています。)

# %% [markdown]
# ### 収集した画像の確認
#
# 読み込んだ画像をタイル状に並べて確認します

# %%
# 画像の一覧可視化関数
import math
import PIL

def tile_show(imgs, n_col=10):
  h, w = imgs[0].shape[:2]
  assert all([img.shape[:2] == (h, w) for img in imgs])
  n_row = math.ceil(len(imgs) / n_col)
  tile = np.zeros((h*n_row, w*n_col, 3), imgs[0].dtype)
  for i, img in enumerate(imgs):
    row = i // n_col
    col = i % n_col
    y1 = row * h
    y2 = (row+1) * h
    x1 = col * w
    x2 = (col+1) * w
    tile[y1:y2, x1:x2] = img
  
  if not tile.dtype == np.uint8:
    tile -= tile.min()
    tile /= tile.max()
    tile *= 255
    tile = np.clip(tile.astype(np.uint8), 0, 255)
  return PIL.Image.fromarray(tile[..., ::-1])

# %%
print(len(imgs_cat))
tile_show(imgs_cat)
# Out:
# 75
# <PIL.Image.Image image mode=RGB size=640x512 at 0x7F90FC27C790>

# %%
print(len(imgs_dog))
tile_show(imgs_dog)
# Out:
# 54
# <PIL.Image.Image image mode=RGB size=640x384 at 0x7F90FC5D8D60>

# %% [markdown]
# ### 学習データ・テストデータの作成
#
# 収集した画像を学習用とテスト用（精度評価用）に分け、ラベル（正解）を付与する（猫=0、犬=1）。
# 今回は **二値分類** なので、変数1つに猫か犬かという意味を持たせることができる（変数が0に近ければ猫である確率が高く、1に近ければ犬である確率が高い）。
#
#
# 3クラス以上の分類 **多クラス分類** では、カテゴリの変数をone-hot encodingという手法でベクトルに変換してから用いることが一般的である。なお、二値分類でもone-hot表現は可能で、こちらの方がいい精度が出る（気がする）ので今回はこちらを使う。
#
# <img src="https://smart-hint.com/wp-content/uploads/2021/11/image-47.png" width="500"><a href="https://smart-hint.com/python/dummies/">src</a>
#
#
# また、画像処理では、入力画像を少数で[-1, 1]の範囲に正規化して用いることが多い。すなわち、`np.uint8`[0, 255]を`np.float32`[-1, 1]に変換する。
#
# 入力の画像とラベルは、次に作成するモデルの入出力とマッチするように作成する。

# %%
import tensorflow as tf

# 学習データとテストデータの作成
test_rate = 0.2
n_cat_test = int(len(imgs_cat) * test_rate)
n_dog_test = int(len(imgs_dog) * test_rate)

cat_test, cat_train = imgs_cat[:n_cat_test], imgs_cat[n_cat_test:]
dog_test, dog_train = imgs_dog[:n_dog_test], imgs_dog[n_dog_test:]

# ndarrayの結合, dtypeをfloat32に変更, [-1,1]に正規化
train_X = np.concatenate([cat_train, dog_train], axis=0)
train_X = train_X.astype(np.float32)
train_X = ((train_X / 255.) - 0.5) * 2
test_X = np.concatenate([cat_test, dog_test], axis=0)
test_X = test_X.astype(np.float32)
test_X = ((test_X / 255.) - 0.5) * 2

# 正規化の確認。train_Xに含まれる全画素の輝度のヒストグラム
plt.hist(train_X.flatten())

# ラベルを作成。猫=0、犬=1として設定
train_y = np.array([0.] * len(cat_train) + [1.] * len(dog_train)).astype(np.float32)
test_y = np.array([0.] * len(cat_test) + [1.] * len(dog_test)).astype(np.float32)
print(train_y.shape)

# one-hot encoding
train_y = tf.keras.utils.to_categorical(train_y, 2)
test_y = tf.keras.utils.to_categorical(test_y, 2)
print(train_y.shape)
# Out:
# (104,)
# (104, 2)

# %% [markdown]
# ### モデルの作成
#
# 今回はVGG16という畳み込みニューラルネットワークを用います。
# 有名なモデルはtensorflwoフレームワークに組み込まれており、呼び出すだけでモデルが使用できます。

# %%
from tensorflow.keras.applications import VGG16

model = VGG16(
    include_top=True, 
    weights=None, 
    input_shape=(img_size, img_size, 3), 
    classes=2,
    )
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2)                 8194
#
# =================================================================
# Total params: 39,896,898
# Trainable params: 39,896,898
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#   `tf.keras.Model.summary()`メソッドでは、モデルの各レイヤーのテンソルの形が表示されます (`None`は数値が任意であることを示す) 。モデルを1つの大きな関数として考えた時、重要なのは入力と出力です。
# - input:  `input_5 (InputLayer)        [(None, 64, 64, 3)]`
# - output:   `predictions (Dense)         (None, 2)`
#
# このモデルは、「4次元テンソルを入力されると2次元テンソルを出力する関数」と言えます。

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (104, 64, 64, 3)
# (104, 2)

# %% [markdown]
# 学習データ画像`train_X`とinputのshape、正解ラベル`train_y`のとoutputのshapeが一致していることが確認できます。

# %% [markdown]
# #### ニューラルネットワーク
#
# <img src="https://www.esector.co.jp/bpa/img/A19-034.png" width="500">
# <a href="https://www.esector.co.jp/bpa/A19-034.html">src</a>
#
# ニューロンに対応する部分をノードなどと呼ぶ。たいてい1ノードだけで扱うことはなく、層のような構造に例えられるためレイヤーとも呼ばれる
#
# <img src="https://www.imagazine.co.jp/wp-content/uploads/2018/07/086-090_16ISno13_kiso_deep_zu003.jpg" width="500">
# <a href="https://www.imagazine.co.jp/%E7%95%B3%E3%81%BF%E8%BE%BC%E3%81%BF%E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF%E3%81%AE%E3%80%8C%E5%9F%BA%E7%A4%8E%E3%81%AE%E5%9F%BA%E7%A4%8E%E3%80%8D%E3%82%92%E7%90%86%E8%A7%A3%E3%81%99/">src</a>
#
# 畳み込みニューラルネットワーク（CNN）は、神経細胞の発火のルールを、画像の部分領域をベースにしたという点で、人間の視覚処理により近い構造を模していると考えることができる。

# %% [markdown]
# #### 畳み込み処理
#
# <img src="https://axa.biopapyrus.jp/media/CNN_Conv3.png" width="500"><a href="https://axa.biopapyrus.jp/deep-learning/cnn/convolution.html">src</a>
#
# 中央の3x3の配列をfilter, kernel, windowなどと呼ぶ。畳み込みは特定のパターン（模様）を抽出する操作だと考えることもでき、フィルターの内容がパターンを決定する。CNNでは、フィルターの中身を学習によって更新し、学習がうまく進むと画像内の特徴量（猫らしさ、犬らしさの指標になる模様など）が抽出できるようになる。
#
#
# <img src="https://i.stack.imgur.com/wrxLE.png" width="500"><a href="http://web.pdx.edu/~jduh/courses/Archive/geog481w07/Students/Ludwig_ImageConvolution.pdf">src</a>
# カーネルの違いによる畳み込み効果の例

# %% [markdown]
# ### モデルの学習

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(train_X, train_y, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 4/4 [==============================] - 24s 336ms/step - loss: 0.6926 - accuracy: 0.5769
# Epoch 2/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.6904 - accuracy: 0.5769
# Epoch 3/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.6863 - accuracy: 0.5769
# Epoch 4/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.6790 - accuracy: 0.5769
# Epoch 5/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.6646 - accuracy: 0.5769
# Epoch 6/30
# 4/4 [==============================] - 0s 45ms/step - loss: 0.6364 - accuracy: 0.5769
# Epoch 7/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5833 - accuracy: 0.5769
# Epoch 8/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5041 - accuracy: 0.6154
# Epoch 9/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.4121 - accuracy: 0.9038
# Epoch 10/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.3333 - accuracy: 0.9808
# Epoch 11/30
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2683 - accuracy: 0.9808
# Epoch 12/30
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1946 - accuracy: 0.9904
# Epoch 13/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1065 - accuracy: 0.9712
# Epoch 14/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0554 - accuracy: 0.9808
# Epoch 15/30
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0411 - accuracy: 0.9808
# Epoch 16/30
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0369 - accuracy: 0.9808
# Epoch 17/30
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0229 - accuracy: 0.9904
# Epoch 18/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 19/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 20/30
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 21/30
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 22/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 23/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0160 - accuracy: 0.9904
# Epoch 24/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0164 - accuracy: 0.9904
# Epoch 25/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 26/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 27/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 28/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 29/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 30/30
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0011 - accuracy: 1.0000

# %%
# 学習過程の可視化
fig, ax1 = plt.subplots()
ax1.plot(history.history['loss'], label='(left) loss')
ax1.set_xlabel('epoch')
ax1.set_ylabel('loss')
ax2 = ax1.twinx()
ax2.plot(history.history['accuracy'], label='(right) accuracy', c='r')
ax2.set_ylabel('accuracy')
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2, loc='center left')
plt.show()

# %% [markdown]
# ### 学習したモデルのテスト
#
# テストデータから1枚、画像を取り出して学習したモデルに適用してみる。
# outputは`tf.Tensor`という型であり、`tf.Tensor.numpy()`メソッドによりnumpyの数値として情報を取り出すことができる。

# %%
# [-1,1]に正規化されている画像を表示する関数
def show_standardized_img(img):
  img -= img.min()
  img /= img.max()
  img *= 255
  img = np.clip(img, 0, 255).astype(np.uint8)
  return PIL.Image.fromarray(img[..., ::-1])

# %%
import random
ix = random.randint(0, len(test_X)-1)
show_standardized_img(test_X[ix])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8FF81CB550>

# %%
output = model(test_X[ix][np.newaxis], training=False)
print(output)
print(output.numpy())
# Out:
# tf.Tensor([[0. 1.]], shape=(1, 2), dtype=float32)
# [[0. 1.]]

# %% [markdown]
# `output`の`shape`は (1, 2) となっているが、これは実質的には長さ2のベクトルであり、「猫である確率」と「犬である確率」の順で格納されている。

# %%
vector = output.numpy()[0]
print('猫である確率:', f'{vector[0]:.3f}')
print('犬である確率:', f'{vector[1]:.3f}')
# Out:
# 猫である確率: 0.000
# 犬である確率: 1.000

# %% [markdown]
# テスト画像の表示とモデルの出力を関数でひとまとめにし、何度か実行してモデルの性能の感覚をつかむ。

# %%
def sample_and_predict(model, X):
  ix = random.randint(0, len(X)-1)
  output = model(X[ix][np.newaxis], training=False)
  vector = output.numpy()[0]
  print('猫である確率:', f'{vector[0]:.3f}')
  print('犬である確率:', f'{vector[1]:.3f}')
  return show_standardized_img(X[ix])

# %%
sample_and_predict(model, test_X)
# Out:
# 猫である確率: 1.000
# 犬である確率: 0.000
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8FF81CB970>

# %% [markdown]
# ### 精度評価
#
# 混合行列 (confusion matrix) を作成する。クラス分類の問題では、正解率や感度など、1つの数字で表現される指標がいくつか存在するが、指標それぞれが見える部分と見えない部分を持つ。
#
# confusion matrixは全ての指標の元になる行列であるので、これさえ載せておけば漏れなく全体を把握することができる。
#
# 今回は「猫と判定すること」を陽性 (positive) として考える。
#
# <img src="https://www.naukri.com/learning/articles/wp-content/uploads/sites/11/2022/03/Confusion-matrix-1.png" width="500"><a href="https://www.naukri.com/learning/articles/web-stories/confusion-matrix-in-machine-learning/">src</a>

# %%
# confusion matrixの算出
true = np.argmax(test_y, axis=1)
test_y_hat = model.predict(test_X)
pred = np.argmax(test_y_hat, axis=1)

confmat = tf.math.confusion_matrix(true, pred).numpy()
confmat
# Out:
# 1/1 [==============================] - 1s 641ms/step
# array([[15,  0],
#        [ 1,  9]], dtype=int32)

# %% [markdown]
# confusion matrixは包括的な情報ではあるものの、ぱっと見ではよくわからないので指標も計算する。
# ポイント：別名があったり日本語訳がしっくりこなかったりわかりにくい。覚えるというよりは意味合いを把握することが大事
#
# <img src="https://cdn-ssl-devio-img.classmethod.jp/wp-content/uploads/2015/08/Untitled.png"><a href="https://dev.classmethod.jp/articles/aml-evaluation-measures/">src</a>
#
# - 正解率 Accuracy
# $ \frac{TP + TN}{TP + FP + FN + TN} $
#
# - 感度 Sensitivity (Recall, True Positive Rate 再現率 検出率 真陽性率)
# $ \frac{TP}{TP + FN} $
# 疾病検査を例にすると、その検査が疾病をとらえる「感度・検出率」となる。(検査で病気と分かった人 / 実際に病気の人)
#
#
# - 特異度 Specificity (True Negative Rate 真陰性率)
# $ \frac{TN}{FP + TN} $
# 検査で言えば、検査で陰性だった人 / 実際に陰性の人
#
# - 陽性的中率 Positive Predictive Value (Precision 適合度 精度)
# $ \frac{TP}{TP + FP} $
# 「陽性適中率が高い」とは、「検査結果が陽性と判定された場合に、真の陽性（有病者）である確率が高い」という意味。
#
#
# 他にも山ほどあります [wikipedia](https://en.wikipedia.org/wiki/Evaluation_of_binary_classifiers)

# %%
[[TP, FP], 
 [FN, TN]] = confmat

accuracy = (TP + TN) / (TP + FP + FN + TN)
sensitivity = TP / (TP + FN)
specificity = TN / (FP + TN)
precision = TP / (TP + FP)

print('正解率', accuracy)
print('感度', sensitivity)
print('特異度', specificity)
print('陽性的中率', precision)
# Out:
# 正解率 0.96
# 感度 0.9375
# 特異度 1.0
# 陽性的中率 1.0

# %% [markdown]
# ### 学習モデルの実利用
#
# 学習モデルはデータセット外の実データに適用して初めて役立ちます。
# ここでは例として、画像URLを受け取ると猫か犬か判定してくれるwebサービスを想定します。
#
# (実際のサービス例：[Google Lens](https://lens.google/intl/ja/#:~:text=%E6%A4%8D%E7%89%A9%E3%82%84%E5%8B%95%E7%89%A9,%E7%A2%BA%E8%AA%8D%E3%81%A7%E3%81%8D%E3%81%BE%E3%81%99%E3%80%82))

# %%
# urlから画像を読みこむcv2u.urlread()を使用するためパッケージをインストール
# !pip install python-opencv-utils
import cv2u
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-opencv-utils
#   Downloading python_opencv_utils-0.0.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from python-opencv-utils) (8.4.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from python-opencv-utils) (1.26.15)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from python-opencv-utils) (4.7.0.72)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-opencv-utils) (1.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python->python-opencv-utils) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-opencv-utils) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-opencv-utils) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-opencv-utils) (3.1.0)
# Installing collected packages: python-opencv-utils
# Successfully installed python-opencv-utils-0.0.4

# %%
#@title 犬猫画像判定サービス { run: "auto", vertical-output: true }

labels = {0: 'ネコ', 1: 'イヌ'}

URL = '' #@param {type:"string"}
try:
  img = cv2u.urlread(URL)
except ValueError:
  img = None

if img is None:
  if URL:
    print('!!! 画像が見つかりません !!!')

else:
  X = cv2.resize(img, (img_size, img_size))
  X = ((X.astype(np.float32) / 255.) - 0.5) * 2
  X = X[np.newaxis]
  y = model.predict(X)
  label = labels[np.argmax(y[0])]
  score = np.max(y) * 100
  print(f'これは {score: .1f}% 「{label}」 です！')
  plt.imshow(img[..., ::-1])
  plt.axis("off")
  plt.show()

# %% [markdown]
# ### より良い精度を目指して
#
# - データセットの量を増やす
# 今回のデモでは各クラスの画像の最大量は200枚としました。一般的には学習量を増やせば精度が向上する傾向にあります。
#
# - 質の高いデータセットの準備
# 画像データを可視化するとわかりますが、スクレイピングで得られた画像には全く関係ないものがある程度含まれます。これらを取り除き、質の高いデータセットを構築することが精度向上につながります。
#
# - データの水増し (データ拡張、Data Augmentation)
# データセットの量を増やすのは人力が多く骨が折れます。水増しの手法では、1枚の画像を疑似的に増幅し、枚数が増えたように見せかけます。
# <img src="https://qph.fs.quoracdn.net/main-qimg-7565e09ecc4a93604b9c26c8c2a89bf9-pjlq" width="500"><a href="https://www.quora.com/What-is-data-augmentation-in-CNN">src</a>
#
# - モデルの変更
# VGG16は2014年に開発されたモデルで古いため、よりよいモデルが多く開発されています。
# 代表的なもの: ResNet (2015), EfficientNet (2019)
